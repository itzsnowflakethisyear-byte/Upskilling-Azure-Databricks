# %%
 # %sql

SELECT * FROM parquet.`/Volumes/databrickskrishna/bronze/autovol/copyinto/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
-- CREATE TABLE databrickskrishna.bronze.copyintotbl
-- (
--     order_id string,
--     customer_id string,
--     order_date string,
--     order_amount string,
--     order_status string
-- )

--  In parquet files we hold schema, so check the above data type anf change accordingly

-- Drop the table since its already created
DROP TABLE IF EXISTS databrickskrishna.bronze.copyintotbl;

# %%
# %sql
CREATE TABLE databrickskrishna.bronze.copyintotbl
(
    order_id INT,
    customer_id INT,
    order_date DATE,
    -- order_amount is double, parquet file is so cautious about its schema and doesn't allow anything else so check clearly
    order_amount DOUBLE, 
    order_status string
)

# %%
# %sql
COPY INTO databrickskrishna.bronze.copyintotbl
FROM '/Volumes/databrickskrishna/bronze/autovol/copyinto'
FILEFORMAT = PARQUET
FORMAT_OPTIONS ('mergeSchema'= 'True')
COPY_OPTIONS ("mergeSchema" = 'True')

# %%
# %sql
SELECT * FROM databrickskrishna.bronze.copyintotbl

# %%
# %sql
DESCRIBE HISTORY databrickskrishna.bronze.copyintotbl;

# %%
# %sql
SELECT COUNT(*)
FROM databrickskrishna.bronze.copyintotbl VERSION AS OF 1;
